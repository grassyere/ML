# %%
Белкина Екатерина ИУ5-61Б

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(style="ticks")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from sklearn.datasets import load_wine
wine = load_wine()

# %%
data.columns
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline', 'target'],
#       dtype='object')

# %%
data = pd.DataFrame(data= np.c_[wine['data'], wine['target']],
                     columns= wine['feature_names'] + ['target'])

# %%
data.corr(method='pearson')
# Out:
#                                alcohol  malic_acid  ...   proline    target
# alcohol                       1.000000    0.094397  ...  0.643720 -0.328222
# malic_acid                    0.094397    1.000000  ... -0.192011  0.437776
# ash                           0.211545    0.164045  ...  0.223626 -0.049643
# alcalinity_of_ash            -0.310235    0.288500  ... -0.440597  0.517859
# magnesium                     0.270798   -0.054575  ...  0.393351 -0.209179
# total_phenols                 0.289101   -0.335167  ...  0.498115 -0.719163
# flavanoids                    0.236815   -0.411007  ...  0.494193 -0.847498
# nonflavanoid_phenols         -0.155929    0.292977  ... -0.311385  0.489109
# proanthocyanins               0.136698   -0.220746  ...  0.330417 -0.499130
# color_intensity               0.546364    0.248985  ...  0.316100  0.265668
# hue                          -0.071747   -0.561296  ...  0.236183 -0.617369
# od280/od315_of_diluted_wines  0.072343   -0.368710  ...  0.312761 -0.788230
# proline                       0.643720   -0.192011  ...  1.000000 -0.633717
# target                       -0.328222    0.437776  ... -0.633717  1.000000
#
# [14 rows x 14 columns]

# %%
data.corr(method='kendall')
# Out:
#                                alcohol  malic_acid  ...   proline    target
# alcohol                       1.000000    0.093844  ...  0.449387 -0.238984
# malic_acid                    0.093844    1.000000  ... -0.044660  0.247494
# ash                           0.170154    0.158178  ...  0.171574 -0.038085
# alcalinity_of_ash            -0.212978    0.210119  ... -0.313218  0.449402
# magnesium                     0.250506    0.050869  ...  0.343016 -0.184992
# total_phenols                 0.209099   -0.174929  ...  0.280203 -0.590404
# flavanoids                    0.191087   -0.211918  ...  0.263661 -0.725255
# nonflavanoid_phenols         -0.109554    0.175129  ... -0.174108  0.379234
# proanthocyanins               0.133526   -0.168714  ...  0.204172 -0.450225
# color_intensity               0.434353    0.195607  ...  0.316632  0.065124
# hue                          -0.021717   -0.388707  ...  0.143508 -0.479229
# od280/od315_of_diluted_wines  0.061513   -0.162909  ...  0.151559 -0.607572
# proline                       0.449387   -0.044660  ...  1.000000 -0.406260
# target                       -0.238984    0.247494  ... -0.406260  1.000000
#
# [14 rows x 14 columns]

# %%
data.corr(method='spearman')
# Out:
#                                alcohol  malic_acid  ...   proline    target
# alcohol                       1.000000    0.140430  ...  0.633580 -0.354167
# malic_acid                    0.140430    1.000000  ... -0.057466  0.346913
# ash                           0.243722    0.230674  ...  0.253163 -0.053988
# alcalinity_of_ash            -0.306598    0.304069  ... -0.456090  0.569792
# magnesium                     0.365503    0.080188  ...  0.507575 -0.250498
# total_phenols                 0.310920   -0.280225  ...  0.419470 -0.726544
# flavanoids                    0.294740   -0.325202  ...  0.429904 -0.854908
# nonflavanoid_phenols         -0.162207    0.255236  ... -0.270112  0.474205
# proanthocyanins               0.192734   -0.244825  ...  0.308249 -0.570648
# color_intensity               0.635425    0.290307  ...  0.457096  0.131170
# hue                          -0.024203   -0.560265  ...  0.207740 -0.616570
# od280/od315_of_diluted_wines  0.103050   -0.255185  ...  0.253266 -0.743787
# proline                       0.633580   -0.057466  ...  1.000000 -0.576383
# target                       -0.354167    0.346913  ... -0.576383  1.000000
#
# [14 rows x 14 columns]

# %%
fig, ax = plt.subplots(figsize=(8,8)) 
sns.scatterplot(ax=ax, x='total_phenols', y='alcohol', data=data)

# %%
fig, ax = plt.subplots(figsize=(8,8)) 
sns.heatmap(data.corr(), annot=True, fmt='.1f')

# %%
# проверим есть ли пропущенные значения
data.isnull().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# target                          0
# dtype: int64
